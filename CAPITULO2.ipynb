# %%
#Pacote de imagens
from IPython.display import Image

# %% [markdown]
# # Capítulo 2: Git/GitHub

# %%
Image(filename = r'C:\Users\breno\OneDrive\Documentos\Faculdade\FIAP\Conteudo\2024\Fase 2\Capítulo 2/img_git.jpg', width=1000, height=1000)

# %% [markdown]
# <img src =" ">

# %% [markdown]
# ## 1. Configurando o usuário do Git

# %% [markdown]
# > Nome

# %%
git config --global user.name "Breno Ferrari"

# %% [markdown]
# > E-mail

# %%
git config --global user.name "Breno Ferrari"

# %% [markdown]
# ## 2. Acessando uma pasta

# %%
cd CAMINHO_PASTA

# %%
cd OneDrive\Documentos\Faculdade\FIAP\Conteudo\2024\How To\GIT

# %% [markdown]
# ## 3. Iniciando um repositório

# %%
git init

# %% [markdown]
# ## 4. Verificando o status do repositório

# %%
git status

# %% [markdown]
# ## 5. Adicionando um arquivo ao repositório

# %%
git add NOME_ARQUIVO.extensao

# %% [markdown]
# Para adicionar todos os arquivos de uma única vez, basta usar o "git add ."

# %%
git add .

# %% [markdown]
# ## 6. Subindo o arquivo para o repositório (commit)

# %%
git commit BRANCH "DESCRIÇÃO"

# %% [markdown]
# Neste caso, "-m" representa a branch master.

# %%
#Exemplo:
git commit -m "primeira versao"

# %% [markdown]
# ## 7. Verificando a branch atual

# %%
git branch

# %% [markdown]
# ## 8. Criando e alterando a branch

# %% [markdown]
# Criando uma branch:

# %%
git branch NOME_BRANCH

# %%
#Exemplo:
git branch teste_branch

# %% [markdown]
# Alterando a branch

# %%
git checkout NOME_BRANCH

# %%
#Exemplo
git checkout teste_branch

# %% [markdown]
# A partir do momento que a branch foi alterada, posso seguir com os comandos normais do git.

# %% [markdown]
# ## 9. Listando os arquivos de uma branch

# %% [markdown]
# O ls-tree mostra todos os arquivos presentes em uma branch específica.

# %%
git ls-tree NOME_DA_BRANCH

# %%
#Exemplo:
git ls-tree master

# %% [markdown]
# O git show mostra o último commit e tudo que foi alterado deste então.

# %%
git show NOME_DA_BRANCH

# %%
#Exemplo:
git show teste_branch

# %% [markdown]
# ## 10. Atualizando a master com as mudanças da branch

# %% [markdown]
# Para passar as mudanças feitas em uma branch para a master, basta retornar a branch master e realizar o merge entre as branchs.

# %%
git checkout master

# %%
git merge teste_branch

# %% [markdown]
# Após passar as mudanças da branch para a master, é necessário removê-la.

# %%
git branch -d teste_branch

# %% [markdown]
# ## 11. Diferença entre arquivos/branchs

# %% [markdown]
# ## 12. Conexão entre repositório local e remoto

# %% [markdown]
# Para fazer a conexão entre o repositório local (máquina) e o remoto (git), posso utilizar o token de acesso pessoal disponível no próprio GitHub ou a conexão via SSH.

# %% [markdown]
# ### 12.1 Token

# %% [markdown]
# Para iniciar, é necessário gerar o token de acesso pessoal no próprio GitHub.
#
# Com o token em mãos, basta criar a conexão entre os repositórios pelos comandos no Git CMD.

# %% [markdown]
# No Git CMD, devo utilizar o seguinte comando:

# %%
git remote add origin https://<TOKEN>@github.com.br/<NOME_USUARIO>/<NOME_REPOSITORIO_REMOTO.git>

# %%
#Exemplo:
git remote add origin https:////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@github.com/FerrariBr1105/FIAP_FASE2_CAP2.git

# %% [markdown]
# Após essa sequência de comandos, os repositórios estão interligados.
#
# Feito isso, preciso "empurrar" (push) os arquivos que estão no repositório local para o remoto.

# %%
git push https://<TOKEN>@github.com.br/<NOME_USUARIO>/<NOME_REPOSITORIO_REMOTO.git>

# %%
#Exemplo:
git push https://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@github.com/FerrariBr1105/FIAP_FASE2_CAP2.git

# %% [markdown]
# ### 12.2 SSH
